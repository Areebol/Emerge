# %%
from utils.load_config import load_config
from utils.load_data import load_token_levels, load_sentence_levels
from utils.plotter import plot_sentence_token_level, plot_level, plot_sentence_entropy
import os
def plot_family_data(model_familys=["llama_2"],data_type="xsum_examples"):
    model_cfg = "./config/models.yaml"
    # 加载模型s
    model_configs = []
    for key in model_familys:
        model_configs += load_config(model_cfg)[f"paths_{key}"]
    # 读取数据
    _, token_levels = load_token_levels(model_configs,data_type)
    models_configs, sentence_levels = load_sentence_levels(model_configs,data_type)
    if models_configs:
        save_path = f"./picture/{data_type}/{model_familys}"
        save_path = None
        # os.makedirs(save_path,exist_ok=True)
        # 绘图
        plot_sentence_token_level("token_level_sentence_level",models_configs,token_levels,sentence_levels,save_path)
        plot_level("token_level",model_configs,token_levels,save_path)
        plot_level("sentence_level",model_configs,sentence_levels,save_path)

# %% [markdown]
# # Data type:xsum_examples

# %% [markdown]
# ## Model:LLama2

# %%
plot_family_data(["llama_2"],data_type="xsum_examples")
# Out:
# loading file ./exp/SentenceEntropy/xsum_examples/llama2_7b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/llama2_chat_7b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/llama2_13b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/llama2_chat_13b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/llama2_70b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/llama2_chat_70b.csv

# %% [markdown]
# ## Model:Qwen

# %%
plot_family_data(["qwen"],data_type="xsum_examples")
# Out:
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_0.5b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_0.5b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1.8b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_4b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_4b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_7b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_7b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_14b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_14b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_32b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_32b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_72b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_chat_72b.csv

# %% [markdown]
# ## Model:Qwen1

# %%
plot_family_data(["qwen_1"],data_type="xsum_examples")
# Out:
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_1.8b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_7b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_chat_7b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_14b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_chat_14b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_72b.csv
# loading file ./exp/SentenceEntropy/xsum_examples/qwen_1_chat_72b.csv

# %% [markdown]
# # Data type:code_examples

# %% [markdown]
# ## Model:LLamaCode

# %%
plot_family_data(["llama_code","llama_code_instruct"],data_type="Code_examples")
# Out:
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_7b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_13b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_34b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_70b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_instruct_7b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_instruct_13b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_instruct_34b.csv
# loading file ./exp/SentenceEntropy/Code_examples/llamaCode_instruct_70b.csv

# %% [markdown]
# # Data type:cot_examples

# %% [markdown]
# ## Model:LLama2

# %%
plot_family_data(["llama_2"],data_type="Cot_examples")
# Out:
# loading file ./exp/SentenceEntropy/Cot_examples/llama2_7b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/llama2_chat_7b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/llama2_13b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/llama2_chat_13b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/llama2_70b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/llama2_chat_70b.csv

# %% [markdown]
# ## Model:Qwen

# %%
plot_family_data(["qwen"],data_type="Cot_examples")
# Out:
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_0.5b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_0.5b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1.8b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_4b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_4b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_7b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_7b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_14b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_14b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_32b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_32b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_72b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_chat_72b.csv

# %% [markdown]
# ## Model:Qwen1

# %%
plot_family_data(["qwen_1"],data_type="Cot_examples")
# Out:
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_1.8b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_7b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_chat_7b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_14b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_chat_14b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_72b.csv
# loading file ./exp/SentenceEntropy/Cot_examples/qwen_1_chat_72b.csv

# %% [markdown]
# # Data type:h3c Human

# %% [markdown]
# ## Model:LLama2

# %%
plot_family_data(["llama_2"],data_type="hc3_human_examples")
# Out:
# loading file ./exp/SentenceEntropy/hc3_human_examples/llama2_7b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/llama2_chat_7b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/llama2_13b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/llama2_chat_13b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/llama2_70b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/llama2_chat_70b.csv

# %% [markdown]
# ## Model:Qwen

# %%
plot_family_data(["qwen"],data_type="hc3_human_examples")
# Out:
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_0.5b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_chat_0.5b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1.8b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_4b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_chat_4b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_7b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_chat_7b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_14b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_chat_14b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_32b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_chat_32b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_72b.csv
# ...

# %% [markdown]
# ## Model:Qwen1

# %%
plot_family_data(["qwen_1"],data_type="hc3_human_examples")
# Out:
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_1.8b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_7b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_chat_7b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_14b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_chat_14b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_72b.csv
# loading file ./exp/SentenceEntropy/hc3_human_examples/qwen_1_chat_72b.csv

# %% [markdown]
# # Data type:Poem Sentiment Classification

# %% [markdown]
# ## Model:Qwen1

# %%
plot_family_data(["qwen_1"],data_type="poem_sentiment_classification")
# Out:
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_1.8b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_chat_1.8b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_7b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_chat_7b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_14b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_chat_14b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_72b.csv
# loading file ./exp/SentenceEntropy/poem_sentiment_classification/qwen_1_chat_72b.csv
